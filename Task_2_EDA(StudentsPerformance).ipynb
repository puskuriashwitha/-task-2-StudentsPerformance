# %% [markdown]
# <a href="https://colab.research.google.com/github/puskuriashwitha/-task-2-StudentsPerformance/blob/main/Task_2_EDA(StudentsPerformance).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1️⃣ Import Required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 2️⃣ Load the Dataset
df = pd.read_csv("StudentsPerformance.csv")
print("Shape of the dataset:", df.shape)
print("\nFirst 5 rows:\n", df.head())

# 3️⃣ Check Data Types & Basic Info
print("\nData Types:\n")
print(df.dtypes)

print("\nDataset Info:\n")
print(df.info())

# 4️⃣ Check for Missing Values
print("\nMissing Values in Each Column:\n")
print(df.isnull().sum())

# 5️⃣ Check Unique Values / Value Counts (for Categorical Columns)
for col in df.select_dtypes(include='object').columns:
    print(f"\nValue counts for {col}:\n")
    print(df[col].value_counts())

# 6️⃣ Summary Statistics for Numeric Columns
print("\nSummary Statistics:\n")
print(df.describe())

# 7️⃣ Histograms for Score Columns
df[['Math_Score', 'Reading_Score', 'Writing_Score']].hist(figsize=(12, 6), bins=10)
plt.suptitle("Histograms of Scores")
plt.show()

# 8️⃣ Boxplots for Outliers Detection
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[['Math_Score', 'Reading_Score', 'Writing_Score']])
plt.title("Boxplot for Scores")
plt.xticks(rotation=45)
plt.show()

# 9️⃣ Correlation Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# 🔟 Pairplot for Relationships
sns.pairplot(df[['Math_Score', 'Reading_Score', 'Writing_Score']])
plt.suptitle("Pairplot of Scores", y=1.02)
plt.show()
# Out:
# Shape of the dataset: (30, 5)
#
# First 5 rows:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0          65             86             67               78            2021
# 1          64             85             71               80            2019
# 2          76             77             77               84            2021
# 3          80             76             75               75            2021
# 4          63             91             62               90            2019
#
# Data Types:
#
# Math_Score         int64
# Reading_Score      int64
# Writing_Score      int64
# Placement_Score    int64
# Club_Join_Date     int64
# dtype: object
#
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       30 non-null     int64
# ...
